# %%
import openpyxl as xl
import os
mydir = 'C:/Users/asuresh/python/BOM_formatting'
for file in os.listdir(mydir):
    if file.endswith('L1 BOMs 2022.xlsx'):
        wb = xl.load_workbook(file)
        for sheet in wb.sheetnames:
            if sheet.lower().endswith("list") or sheet.lower() == "standard" or sheet[:3] == 'MOT':
                continue
#             print(sheet.split()[0], wb[sheet].cell(row = 11, column = 16).value)
    # if file.endswith('2022.xlsx'):
    #     wb2.save(file)
# wb = xl.load_workbook('L1 BOMs 2022.xlsx')
# check = True
# for i in wb.sheetnames:
#     print('')
#     print(i, end=' ')
#     if check:
#         check = False
#         continue
#     for row in [4]:
#         print(wb[i].cell(row = row, column = 4).value, end=' ')

# %%
import openpyxl as xl
import os
mydir = 'C:/Users/asuresh/python/BOM_formatting'
read = xl.load_workbook("MES vs SAP compare.xlsx")
for file in os.listdir(mydir):
    if file.endswith('L1 BOMs 2022.xlsx'):
        wb = xl.load_workbook(file)
        i = 2
        for sheet in wb.sheetnames:
            if sheet.lower().endswith("list") or sheet.lower() == "standard" or sheet[:3] == 'MOT':
                continue
            read["List"].cell(row=i, column=1).value = sheet.split()[0]
            read["List"].cell(row=i, column=2).value = wb[sheet].cell(row=11, column=16).value
            i += 1
            print(sheet.split()[0], wb[sheet].cell(row=11, column=16).value)
read.save("MES vs SAP compare.xlsx")
    # if file.endswith('2022.xlsx'):
    #     wb2.save(file)
# wb = xl.load_workbook('L1 BOMs 2022.xlsx')
# check = True
# for i in wb.sheetnames:
#     print('')
#     print(i, end=' ')
#     if check:
#         check = False
#         continue
#     for row in [4]:
#         print(wb[i].cell(row = row, column = 4).value, end=' ')
# Out:
# 51530 BP_IMP_BAS_1
# 51803 BP_IMP_BAS_1
# 51804 BP_IMP_BAS_1
# 51807 BP_IMP_BAS_1
# 51809 BP_IMP_BAS_1
# 51810 BP_IMP_BAS_1
# 51811 BP_IMP_BAS_1
# 51830 BP_IMP_BAS_1
# 51830 BP_IMP_BAS_1
# 51836 BP_IMP_BAS_1
# 51839 BP_IMP_BAS_1
# 51858 BP_IMP_BAS_1
# 51861 BP_IMP_BAS_1
# 51873 BP_IMP_BAS_1
# 51899 BP_IMP_BAS_1
# 51900331 BP_IMP_BAS_1
# 51901 BP_IMP_BAS_1
# 51903 BP_IMP_BAS_1
# 51904 BP_IMP_BAS_1
# 51908 BP_IMP_BAS_1
# 51911 BP_IMP_BAS_1
# 51913331 BP_IMP_BAS_1
# 51915 BP_IMP_BAS_1
# 51927 BP_IMP_BAS_1
# 51929 BP_IMP_BAS_7
# 51933 BP_MUL_BAS_1
# 51941 BP_IMP_BAS_7
# 51989 BP_IMP_BAS_1
# 52500 BP_MUL_BAS_1
# 52505 BP_MUL_BAS_1
# 52513 BP_MUL_BAS_1
# 52514 BP_MUL_BAS_1
# 52520 BP_MUL_BAS_1
# 54000 BP_IMP_BAS_1
# 54004 BP_IMP_BAS_1
# 57502 BP_IMP_BAS_1
# 57518 BP_IMP_BAS_1
# 57520331 BP_IMP_BAS_1
# 59050 BP_IMP_BAS_1
# 59214 BP_IMP_BAS_1
# 59234 BP_IMP_BAS_1
# 59237 BP_IMP_BAS_1
# 5T4000 BP_IMP_BAS_1
# 5T4001 BP_IMP_BAS_1
# 5T4003 BP_IMP_BAS_1
# 5T4004 BP_IMP_BAS_1
